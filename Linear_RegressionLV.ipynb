# %% [markdown]
# <a href="https://colab.research.google.com/github/likkie2v/AI-ML-STTP-2026/blob/main/Linear_RegressionLV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data = pd.read_csv('/content/Salary_Data.csv')

# %%
data.shape
# Out:
# (30, 2)

# %%
data
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
data.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x = data[['YearsExperience']]

# %%
x.shape
# Out:
# (30, 1)

# %%
y = data['Salary']

# %%
y.shape
# Out:
# (30,)

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size=0.8,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred = lr.predict(xtest)

# %%
xtest.shape
# Out:
# (6, 1)

# %%
ytest
# Out:
# 2      37731
# 28    122391
# 13     57081
# 10     63218
# 26    116969
# 24    109431
# Name: Salary, dtype: int64

# %%
from sklearn.metrics import r2_score

# %%
r2score = r2_score(ytest,ypred)

# %%
r2score
# Out:
# 0.988169515729126

# %%
plt.scatter(xtest,ytest,color='blue',label='actual')
plt.scatter(xtest,ypred,color='red',label='computed')
plt.plot(xtest,ypred,color='orange',label='line of regression')
plt.legend()
